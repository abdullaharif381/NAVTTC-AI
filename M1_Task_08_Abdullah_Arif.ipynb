# %%
import calculator as calc

# %%
choice = 0
while(choice>-1):

    print("\n(1) Addition\t(2) Subtraction\n(3) Multiply\t(4) Division\n(5) Factorial\t(6) Modulus\n(7) Power\t(8) Percentage\n (9) Fibonacci Series upto n \n(10) Secret Operation \n\nEnter operation no.: ")
    choice=int(input())
    if(choice==1):
        x=int(input("x = "))
        y=int(input("y = "))
        print("Addition (x+y):\t",calc.add(x,y))
    elif(choice==2):
        x=int(input("x = "))
        y=int(input("y = "))
        print("Subtraction (x-y):\t",calc.sub(x,y))
    elif(choice==3):
        x=int(input("x = "))
        y=int(input("y = "))
        print("Multiplication (x*y):\t",calc.mul(x,y))
    elif(choice==4):
        x=int(input("x = "))
        y=int(input("y = "))
        print("Division (x/y):\t",calc.div(x,y))
    elif(choice==5):
        x=int(input("x = "))        
        print("Factorial of x:\t",calc.fac(x))
    elif(choice==6):
        x=int(input("x = "))
        y=int(input("y = "))
        print("Modulus (x%y):\t",calc.mod(x,y))
    elif(choice==7):
        x=int(input("x = "))
        y=int(input("y = "))
        print("Power (x^y):\t" ,calc.power(x,y))
    elif(choice==8):
        x=int(input("x = "))
        y=int(input("y = "))
        print("Percentage of x out of y:\t",calc.per(x,y))
    elif(choice ==9):
        calc.fibonacci()
    elif(choice==10):
        
        print("Using list comprehension...")
        x=(1,2,10,20)       
        print("Secret Answer:\t",calc.secret(x))

    else:
        break;
# Out:
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 1
# x = 30
# y = 80
# Addition (x+y):	 110
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 2
# x = 90
# y = 50
# Subtraction (x-y):	 40
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 3
# x = 40
# y = 20
# Multiplication (x*y):	 800
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 4
# x = 800
# y = 20
# Division (x/y):	 40.0
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 5
# x = 7
# Factorial of x:	 5040
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 6
# x = 81
# y = 9
# Modulus (x%y):	 0
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 7
# x = 3
# y = 4
# Power (x^y):	 81
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 8
# x = 81
# y = 900
# Percentage of x out of y:	 9.0
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 9
# n = 5
# n = 5
# 1
# 1
# 2
# 3
# 5
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# 10
# Using list comprehension...
# Secret Answer:	 [(1.0605752387249068e-16+1.7320508075688772j), (1.4998798865218462e-16+2.449489742783178j), (3.353833384347519e-16+5.477225575051661j), (4.743036658083919e-16+7.745966692414834j)]
#
# (1) Addition	(2) Subtraction
# (3) Multiply	(4) Division
# (5) Factorial	(6) Modulus
# (7) Power	(8) Percentage
#  (9) Fibonacci Series upto n
# (10) Secret Operation
#
# Enter operation no.:
# -1

# %%
import shapes as sp
choice = 0
shape = 0
while(choice!=-1):

    print("1. Triangle")
    print("2. Circle")
    print("3. Square")
    print("4. Rectangle")
    print("5. Right-Angled Triangle")
    print("6. Cube")
    print("7. Cuboid")
    print("8. Sphere")


    choice=int(input("Shape No.: "))
    if(choice == 1): 
        x=int(input("side a= "))
        y=int(input("side b= "))
        z=int(input("side c= "))
        print("Area=",sp.tri_area(x,y,z))
    elif(choice == 2):
        r=int(input("radius = "))
        print("Area = ", sp.circle_area(r))
        print("Circumfrence", sp.circumfrence(r))
    elif(choice==3):
        x=int(input("side length= "))    
        print("Area: ",sp.sq_area(x))
    elif(choice==4):
        x=int(input("length= "))
        y=int(input("width= "))        
        print("Area: ",sp.rec_area(x,y))
    elif(choice==5):
        x=int(input("length= "))
        y=int(input("width= "))
        print("Area = ", sp.right_tri_area(x,y))      

    elif(choice==6):
        x=int(input("side length= "))
        print("Area = ", sp.cube_area(x))      
        print("Volume = ",sp.cube_vol(x)) 

    elif(choice==7):
        x=int(input("side a= "))
        y=int(input("side b= "))
        z=int(input("side c= "))
        print("Area = ", sp.cuboid_area(x,y,z))      
        print("Volume = ",sp.cuboid_vol(x,y,z))   
    elif(choice==8):
        r=int(input("radius = "))
        print("Area = ", sp.sphere_area(r))
        print("Volume: ", sp.sphere_vol(r))
    else:
        break;
# Out:
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: 1
# side a= 9
# side b= 20
# side c= 3
# Area= (4.672954358385779e-15+76.31513611335565j)
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: 2
# radius = 5
# Area =  78.53981625
# Circumfrence 31.4159265
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: 3
# side length= 10
# Area:  100
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: 4
# length= 10
# width= 20
# Area:  200
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: 4
# length= 90
# width= 20
# Area:  1800
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: 5
# length= 10
# width= 20
# Area =  100.0
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: 6
# side length= 8
# Area =  384
# Volume =  512
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: 7
# side a= 9
# side b= 10
# side c= 20
# Area =  940
# Volume =  1800
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: 8
# radius = 5
# Area =  314.159265
# Volume:  523.5987749999999
# 1. Triangle
# 2. Circle
# 3. Square
# 4. Rectangle
# 5. Right-Angled Triangle
# 6. Cube
# 7. Cuboid
# 8. Sphere
# Shape No.: -1

# %%
import tuples_module as tpm
a=(1,2,3,4,5)
print("\n","\t\tTupple: ",a,"\n")
print("Tuple to List Convertor: ",tpm.to_list(1,2,3,4,5))
b=((1,2,3,4,5,6,10,8,12))
print("\n","\t\tTupple: ",b,"\n")
print("Even Number Count: ", tpm.count_even(1,2,3,4,5,6,10,8,12))
c=(29,20,12,30,22,1,0,25,19,90,35,38,81,20,10)
print("\n","\t\tTupple: ",c,"\n")
print("Numbers > 20 = ", tpm.above_20(29,20,12,30,22,1,0,25,19,90,35,38,81,20,10))
# Out:
#  		Tupple:  (1, 2, 3, 4, 5)
#
# Tuple to List Convertor:  [1, 2, 3, 4, 5]
#
#  		Tupple:  (1, 2, 3, 4, 5, 6, 10, 8, 12)
#
# Even Number Count:  6
#
#  		Tupple:  (29, 20, 12, 30, 22, 1, 0, 25, 19, 90, 35, 38, 81, 20, 10)
#
# Numbers > 20 =  [29, 30, 22, 25, 90, 35, 38, 81]
