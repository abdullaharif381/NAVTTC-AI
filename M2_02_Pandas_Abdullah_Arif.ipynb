# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel("sales_data_sample.xlsx")

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
display(df.head(5))
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0       2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  2003-07-05 00:00:00  Shipped       2         5     2003  ...
# 2  2003-01-07 00:00:00  Shipped       3         7     2003  ...
# 3       8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  2003-10-10 00:00:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
print("Number of columns:",df.loc[0].count(),"\nNumber of rows: ",df["STATUS"].count())
# Out:
# Number of columns: 23
# Number of rows:  2823

# %%
print("Average Sales: ", int(sum(df["SALES"])/2823))
# Out:
# Average Sales:  3553

# %%
df['SALES'].groupby([df['PRODUCTLINE']]).mean()
#Calculate the average sales for each product category and display the result.
# Out:
# PRODUCTLINE
# Classic Cars        4053.377104
# Motorcycles         3523.831843
# Planes              3186.286176
# Ships               3053.150128
# Trains              2938.226883
# Trucks and Buses    3746.810100
# Vintage Cars        3135.339110
# Name: SALES, dtype: float64

# %%
product = df["PRODUCTLINE"].value_counts()
product
# Out:
# Classic Cars        967
# Vintage Cars        607
# Motorcycles         331
# Planes              306
# Trucks and Buses    301
# Ships               234
# Trains               77
# Name: PRODUCTLINE, dtype: int64

# %%
df.groupby(["PRODUCTLINE"])

# %%
df[(df["SALES"]>10000)].head(5)
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 30         10150               45      100.0                8  10993.5
# 43         10304               47      100.0                6  10172.7
# 44         10312               48      100.0                3  11623.7
# 53         10424               50      100.0                6  12001.0
# 104        10403               66      100.0                9  11886.6
#
#                ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 30        9/19/2003 0:00     Shipped       3         9     2003  ...
# 43   2004-11-10 00:00:00     Shipped       4        10     2004  ...
# 44       10/21/2004 0:00     Shipped       4        10     2004  ...
# 53        5/31/2005 0:00  In Process       2         5     2005  ...
# 104  2005-08-04 00:00:00     Shipped       2         4     2005  ...
#
#                              ADDRESSLINE1  ADDRESSLINE2        CITY STATE  \
# ...

# %%
df = df.sort_values("SALES",ascending=False)
df.head(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 598         10407               76      100.0                2  14082.8
# 744         10322               50      100.0                6  12536.5
# 53          10424               50      100.0                6  12001.0
# 1062        10412               60      100.0                9  11887.8
# 104         10403               66      100.0                9  11886.6
#
#                 ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 598        4/22/2005 0:00     On Hold       2         4     2005  ...
# 744   2004-04-11 00:00:00     Shipped       4        11     2004  ...
# 53         5/31/2005 0:00  In Process       2         5     2005  ...
# 1062  2005-03-05 00:00:00     Shipped       2         5     2005  ...
# 104   2005-08-04 00:00:00     Shipped       2         4     2005  ...
#
#                       ADDRESSLINE1  ADDRESSLINE2       CITY STATE POSTALCODE  \
# ...

# %%
df["PROFIT"]=((df["MSRP"]*df["QUANTITYORDERED"])-df["SALES"])
df.head(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 598         10407               76      100.0                2  14082.8
# 744         10322               50      100.0                6  12536.5
# 53          10424               50      100.0                6  12001.0
# 1062        10412               60      100.0                9  11887.8
# 104         10403               66      100.0                9  11886.6
#
#                 ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 598        4/22/2005 0:00     On Hold       2         4     2005  ...
# 744   2004-04-11 00:00:00     Shipped       4        11     2004  ...
# 53         5/31/2005 0:00  In Process       2         5     2005  ...
# 1062  2005-03-05 00:00:00     Shipped       2         5     2005  ...
# 104   2005-08-04 00:00:00     Shipped       2         4     2005  ...
#
#      ADDRESSLINE2       CITY STATE POSTALCODE COUNTRY TERRITORY  \
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 598         10407               76     100.00                2  14082.80
# 744         10322               50     100.00                6  12536.50
# 53          10424               50     100.00                6  12001.00
# 1062        10412               60     100.00                9  11887.80
# 104         10403               66     100.00                9  11886.60
# ...           ...              ...        ...              ...       ...
# 1818        10419               15      42.67                7    640.05
# 1551        10280               20      28.88               12    577.60
# 2044        10408               15      36.93                1    553.95
# 1287        10407                6      90.19                3    541.14
# 2249        10425               11      43.83                6    482.13
#
#                 ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['SALES'].nlargest(n=10)
# Out:
# 598     14082.8
# 744     12536.5
# 53      12001.0
# 1062    11887.8
# 104     11886.6
# 1995    11739.7
# 44      11623.7
# 1133    11336.7
# 188     11279.2
# 30      10993.5
# Name: SALES, dtype: float64

# %%
df['SALES'].groupby([df['YEAR_ID']]).sum()

#Calculate the sum of sales for each year in the DataFrame.
# Out:
# YEAR_ID
# 2003    3516979.54
# 2004    4724162.60
# 2005    1791486.71
# Name: SALES, dtype: float64

# %%
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 598         False            False      False            False  False
# 744         False            False      False            False  False
# 53          False            False      False            False  False
# 1062        False            False      False            False  False
# 104         False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 1818        False            False      False            False  False
# 1551        False            False      False            False  False
# 2044        False            False      False            False  False
# 1287        False            False      False            False  False
# 2249        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  ADDRESSLINE2   CITY  \
# ...

# %%
df.fillna("CONFIDENTIAL").head(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 598         10407               76      100.0                2  14082.8
# 744         10322               50      100.0                6  12536.5
# 53          10424               50      100.0                6  12001.0
# 1062        10412               60      100.0                9  11887.8
# 104         10403               66      100.0                9  11886.6
#
#                 ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 598        4/22/2005 0:00     On Hold       2         4     2005  ...
# 744   2004-04-11 00:00:00     Shipped       4        11     2004  ...
# 53         5/31/2005 0:00  In Process       2         5     2005  ...
# 1062  2005-03-05 00:00:00     Shipped       2         5     2005  ...
# 104   2005-08-04 00:00:00     Shipped       2         4     2005  ...
#
#       ADDRESSLINE2       CITY         STATE POSTALCODE COUNTRY     TERRITORY  \
# ...

# %%
#Create a new column that calculates the cumulative sum of sales for each product category.
df["CUMSUM"]=df['SALES'].groupby([df['PRODUCTLINE']]).cumsum()
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 1818        10419               15      42.67                7  640.05
# 1551        10280               20      28.88               12  577.60
# 2044        10408               15      36.93                1  553.95
# 1287        10407                6      90.19                3  541.14
# 2249        10425               11      43.83                6  482.13
#
#            ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...       CITY  \
# 1818  5/17/2005 0:00     Shipped       2         5     2005  ...   Salzburg
# 1551  8/17/2004 0:00     Shipped       3         8     2004  ...     Torino
# 2044  4/22/2005 0:00     Shipped       2         4     2005  ...  Minato-ku
# 1287  4/22/2005 0:00     On Hold       2         4     2005  ...   San Jose
# 2249  5/31/2005 0:00  In Process       2         5     2005  ...     Nantes
#
#       STATE POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# ...

# %%
df[df["PRODUCTLINE"]=='Ships']
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1602        10248               48     100.00               10  6960.48
# 1600        10221               49     100.00                1  6804.63
# 2531        10384               49     100.00                1  6397.44
# 1590        10105               43     100.00                9  6341.21
# 1596        10177               50     100.00                7  6083.00
# ...           ...              ...        ...              ...      ...
# 2471        10273               21      65.34                7  1372.14
# 2808        10232               24      49.69                3  1192.56
# 953         10327               25      45.86                5  1146.50
# 2464        10185               21      54.00                3  1134.00
# 2555        10361               24      45.39               14  1089.36
#
#                 ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['SALES'].groupby([df['PRODUCTLINE']]).pct_change().tail(5)

#Calculate the percentage change in sales from the previous row for each product category.
# Out:
# 1818   -0.107820
# 1551   -0.114586
# 2044   -0.040945
# 1287   -0.023125
# 2249   -0.338097
# Name: SALES, dtype: float64

# %%
dff=df.to_csv("updated_sales_data.csv")
dff

# %%
names = ['Ali', 'Arif', 'Kasim', 'Jazib', 'Hamid']
math = np.random.randint(0, 110, size=5)
physics = np.random.randint(0, 110, size=5)
chemistry = np.random.randint(0, 110, size=5)
biology = np.random.randint(0, 110, size=5)
comp=np.random.randint(0,110,size=5)

data = {'Name': names,
        'Mathematics': math,
        'Physics': physics,
        'Chemistry': chemistry,
        'Biology': biology,
       'Computer Science': comp}

students = pd.DataFrame(data,index=np.arange(1,6))

students['Total Marks'] = students['Mathematics'] + students['Physics'] + students['Chemistry'] + students['Biology']+students['Computer Science']
grades=['U','D','C','B','A']
ranges=[0,100,200,300,400,500]
students['Grade'] = pd.cut(students['Total Marks'], ranges, labels=grades)
students.to_csv("students.csv")

# %%
d=pd.read_csv("students.csv")
d
# Out:
#    Unnamed: 0   Name  Mathematics  Physics  Chemistry  Biology  \
# 0           1    Ali           10       24         97       52
# 1           2   Arif           80       18         12       83
# 2           3  Kasim           89       69         53       63
# 3           4  Jazib           26       49         78       89
# 4           5  Hamid           26       14        107       66
#
#    Computer Science  Total Marks Grade
# 0                80          263     C
# 1                45          238     C
# 2                36          310     B
# 3                66          308     B
# 4                27          240     C

# %%
tf=pd.read_table("students.csv")
tf
# Out:
#   ,Name,Mathematics,Physics,Chemistry,Biology,Computer Science,Total Marks,Grade
# 0                         1,Ali,10,24,97,52,80,263,C
# 1                        2,Arif,80,18,12,83,45,238,C
# 2                       3,Kasim,89,69,53,63,36,310,B
# 3                       4,Jazib,26,49,78,89,66,308,B
# 4                      5,Hamid,26,14,107,66,27,240,C

# %%
fd=pd.read_fwf("students.csv")
fd
# Out:
#   ,Name,Mathematics,Physics,Chemistry,Biology,Computer  Science,Total  \
# 0                         1,Ali,10,24,97,52,80,263,C              NaN
# 1                        2,Arif,80,18,12,83,45,238,C              NaN
# 2                       3,Kasim,89,69,53,63,36,310,B              NaN
# 3                       4,Jazib,26,49,78,89,66,308,B              NaN
# 4                      5,Hamid,26,14,107,66,27,240,C              NaN
#
#    Marks,Grade
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
